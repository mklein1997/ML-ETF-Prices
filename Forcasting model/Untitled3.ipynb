# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
df = pd.read_csv('Resources/NDXT0918.csv', parse_dates = ['Date'], index_col = ['Date'])
df.head()
plt.xlabel('Date')
plt.ylabel('Close')
plt.plot(df)
# Out:
# [<matplotlib.lines.Line2D at 0x212110d4a90>,
#  <matplotlib.lines.Line2D at 0x21210aa84a8>,
#  <matplotlib.lines.Line2D at 0x21210aa85c0>,
#  <matplotlib.lines.Line2D at 0x21210aa8630>,
#  <matplotlib.lines.Line2D at 0x21210aa86d8>,
#  <matplotlib.lines.Line2D at 0x21210aa8780>]

# %%
rolling_mean = df.rolling(window = 12).mean()
rolling_std = df.rolling(window = 12).std()
plt.plot(df, color = 'blue', label = 'Original')
plt.plot(rolling_mean, color = 'red', label = 'Rolling Mean')
plt.plot(rolling_std, color = 'black', label = 'Rolling Std')
plt.legend(loc = 'best')
plt.title('Rolling Mean & Rolling Standard Deviation')
plt.show()

# %%
df_log = np.log(df)
plt.plot(df_log)
# Out:
# C:\Users\rvara\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# [<matplotlib.lines.Line2D at 0x2120fec6dd8>,
#  <matplotlib.lines.Line2D at 0x2120ff79518>,
#  <matplotlib.lines.Line2D at 0x2120ff79080>,
#  <matplotlib.lines.Line2D at 0x2120ff79630>,
#  <matplotlib.lines.Line2D at 0x2120ff797b8>,
#  <matplotlib.lines.Line2D at 0x2120ff79828>]

# %%
def get_stationarity(timeseries):
    
    # rolling statistics
    rolling_mean = timeseries.rolling(window=12).mean()
    rolling_std = timeseries.rolling(window=12).std()
    
    # rolling statistics plot
    original = plt.plot(timeseries, color='blue', label='Original')
    mean = plt.plot(rolling_mean, color='red', label='Rolling Mean')
    std = plt.plot(rolling_std, color='black', label='Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    # Dickey–Fuller test:
    result = adfuller(timeseries['Passengers'])
    print('ADF Statistic: {}'.format(result[0]))
    print('p-value: {}'.format(result[1]))
    print('Critical Values:')
    for key, value in result[4].items():
        print('\t{}: {}'.format(key, value))

# %%
rolling_mean = df_log.rolling(window=12).mean()
df_log_minus_mean = df_log - rolling_mean
df_log_minus_mean.dropna(inplace=True)
get_stationarity(df_log_minus_mean)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonAdv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Passengers'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-7c5348aa589b> in <module>
#       2 df_log_minus_mean = df_log - rolling_mean
#       3 df_log_minus_mean.dropna(inplace=True)
# ----> 4 get_stationarity(df_log_minus_mean)
#
# <ipython-input-14-181cc24b7942> in get_stationarity(timeseries)
#      14
#      15     # Dickey–Fuller test:
# ---> 16     result = adfuller(timeseries['Passengers'])
#      17     print('ADF Statistic: {}'.format(result[0]))
#      18     print('p-value: {}'.format(result[1]))
#
# ~\anaconda3\envs\PythonAdv\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# ~\anaconda3\envs\PythonAdv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'Passengers'

# %%
df_log_shift = df_log - df_log.shift()
df_log_shift.dropna(inplace=True)
get_stationarity(df_log_shift)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonAdv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Passengers'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-2bd057403ede> in <module>
#       1 df_log_shift = df_log - df_log.shift()
#       2 df_log_shift.dropna(inplace=True)
# ----> 3 get_stationarity(df_log_shift)
#
# <ipython-input-9-181cc24b7942> in get_stationarity(timeseries)
#      14
#      15     # Dickey–Fuller test:
# ---> 16     result = adfuller(timeseries['Passengers'])
#      17     print('ADF Statistic: {}'.format(result[0]))
#      18     print('p-value: {}'.format(result[1]))
#
# ~\anaconda3\envs\PythonAdv\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# ~\anaconda3\envs\PythonAdv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'Passengers'

# %%
decomposition = seasonal_decompose(df_log) 
model = ARIMA(df_log, order=(2,1,2))
results = model.fit(disp=-1)
plt.plot(df_log_shift)
plt.plot(results.fittedvalues, color='red')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-d409a77d21dd> in <module>
# ----> 1 decomposition = seasonal_decompose(df_log)
#       2 model = ARIMA(df_log, order=(2,1,2))
#       3 results = model.fit(disp=-1)
#       4 plt.plot(df_log_shift)
#       5 plt.plot(results.fittedvalues, color='red')
#
# ~\anaconda3\envs\PythonAdv\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~\anaconda3\envs\PythonAdv\lib\site-packages\statsmodels\tsa\seasonal.py in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     130
#     131     if not np.all(np.isfinite(x)):
# --> 132         raise ValueError("This function does not handle missing values")
#     133     if model.startswith('m'):
#     134         if np.any(x <= 0):
#
# ValueError: This function does not handle missing values

# %%
predictions_ARIMA_diff = pd.Series(results.fittedvalues, copy=True)
predictions_ARIMA_diff_cumsum = predictions_ARIMA_diff.cumsum()
predictions_ARIMA_log = pd.Series(df_log['Passengers'].iloc[0], index=df_log.index)
predictions_ARIMA_log = predictions_ARIMA_log.add(predictions_ARIMA_diff_cumsum, fill_value=0)
predictions_ARIMA = np.exp(predictions_ARIMA_log)
plt.plot(df)
plt.plot(predictions_ARIMA)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-4a2c7c7f6f8f> in <module>
# ----> 1 predictions_ARIMA_diff = pd.Series(results.fittedvalues, copy=True)
#       2 predictions_ARIMA_diff_cumsum = predictions_ARIMA_diff.cumsum()
#       3 predictions_ARIMA_log = pd.Series(df_log['Passengers'].iloc[0], index=df_log.index)
#       4 predictions_ARIMA_log = predictions_ARIMA_log.add(predictions_ARIMA_diff_cumsum, fill_value=0)
#       5 predictions_ARIMA = np.exp(predictions_ARIMA_log)
#
# NameError: name 'results' is not defined
